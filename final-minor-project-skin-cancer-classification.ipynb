# %%
import os
import sys
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf


from keras.callbacks import *
from imblearn.over_sampling import RandomOverSampler 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras.models import Model, Sequential
from keras.layers import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , classification_report

import warnings
warnings.filterwarnings('ignore')

metadata = "/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv"
hmnist_8_8_RGB = "/kaggle/input/skin-cancer-mnist-ham10000/hmnist_8_8_RGB.csv"
hmnist_28_28_RGB = "/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv"
hmnist_8_8_L = "/kaggle/input/skin-cancer-mnist-ham10000/hmnist_8_8_L.csv"
hmnist_28_28_L = "/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_L.csv"


classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
df = pd.read_csv(hmnist_28_28_RGB, delimiter=',')
df.dataframeName = 'hmnist_28_28_RGB.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 10015 rows and 2353 columns

# %%
df.head()

label = df["label"]
data = df.drop(columns=["label"]) 
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2342  pixel2343  \
# 0        197        154        185        202  ...        134        173
# 1        123         93        126        158  ...         82         60
# 2        201        142        160        206  ...        149        167
# 3        143        103        119        171  ...         73         44
# 4        215        162        191        225  ...        201        209
#
#    pixel2344  pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  \
# 0        124        138        183        147        166        185
# 1         39         55         25         14         28         25
# 2        129        143        159        124        142        136
# 3         26         36         25         12         17         25
# 4        166        185        172        135        149        109
#
#    pixel2350  pixel2351
# 0        154        177
# 1         14         27
# 2        104        117
# 3         12         15
# 4         78         92
#
# [5 rows x 2352 columns]

# %%
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number])
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]]
    columnNames = list(df)
    if len(columnNames) > 10:
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
# plotting the labeled data 
plt.figure(figsize = (10,10))
sns.set_style("darkgrid")
sns.countplot(label)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
plotScatterMatrix(df, 20, 10)

# %%
# our dataset is immbalanced, so we try to balanced the data using oversample the data usinfg random points
oversample = RandomOverSampler()
data,label  = oversample.fit_resample(data,label)
data = np.array(data).reshape(-1,28,28,3)
label = np.array(label)
print(type(label))
data.shape
# Out:
# <class 'numpy.ndarray'>
# (46935, 28, 28, 3)

# %%
plt.figure(figsize = (10,10))
sns.set_style("darkgrid")
sns.countplot(label)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
plotScatterMatrix(df, 20, 10)

# %%
X_train , X_test , y_train , y_test = train_test_split(data , label , test_size = 0.2 , random_state = 42)

# %%
def plotImg(img):
    plt.imshow(img)
    plt.title("Skin Cancer Image")
    plt.grid(False)
    plt.axis("off")
    plt.show()

# %%
plotImg(X_train[0])

# %%
fig, axes = plt.subplots(5,5)
fig.set_size_inches(10, 10)
for i in range(5):
    for j in range(5):
        n = np.random.randint(0,1000, 1)
        axes[i,j].imshow(X_train[n].reshape(28,28,3))
    plt.tight_layout()

# %%
#one hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# #Data Augmentation
# datagen = ImageDataGenerator(rescale=(1./255)
#                              ,rotation_range=10
#                              ,zoom_range = 0.1
#                              ,width_shift_range=0.1
#                              ,height_shift_range=0.1)
# testgen = ImageDataGenerator(rescale=(1./255))

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

# %%
#CNN Model
def model1():
    model = Sequential()
    #layer1
    model.add(Rescaling(1./255, input_shape=(28, 28, 3) ))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer2
    model.add(Conv2D(32, (3, 3) , padding='same'))
    model.add(Activation('relu'))
    #layer3
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer4
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    #classfier
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dense(7))
    model.add(Activation('softmax'))
    
    return model
    
    
def model2():
    model = Sequential()
    #layer1
    model.add(Rescaling(1./255, input_shape=(28, 28, 3) ))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer2
    model.add(Conv2D(32, (3, 3) , padding='same'))
    model.add(Activation('relu'))
    #layer3
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer4
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    #classifier
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dense(7))
    model.add(Activation('softmax'))
    
    return model
    
def model3():
    model = Sequential()
    #layer1
    model.add(Rescaling(1./255, input_shape=(28, 28, 3) ))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer2
    model.add(Conv2D(32, (3, 3) , padding='same'))
    model.add(Activation('relu'))
    #layer3
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    #layer4
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    # classifier
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))
    model.add(Dense(7))
    model.add(Activation('softmax'))

    return model
    
    
def model4():
    input_ = Input(shape = [28,28,3])
    layer1 = Conv2D(32 , (3,3) , activation='relu',padding='same' , kernel_initializer='he_normal')(input_)
    pool1 = MaxPooling2D()(layer1)
    normal1 = BatchNormalization()(pool1)
    layer2 = Conv2D(64 , (3,3) , activation='relu',padding='same' , kernel_initializer='he_normal')(normal1)
    layer3 = Conv2D(64 , (3,3) , activation='relu',padding='same' , kernel_initializer='he_normal')(layer2)
    pool2 = MaxPooling2D()(layer3)
    normal2 = BatchNormalization()(pool2)
    layer4 = Conv2D(128 , (3,3) , activation='relu',padding='same' , kernel_initializer='he_normal')(normal2)
    layer5 = Conv2D(128 , (3,3) , activation='relu',padding='same' , kernel_initializer='he_normal')(layer4)
    pool3 = MaxPooling2D()(layer5)
    normal3 = BatchNormalization()(pool3)
    layer6 = Conv2D(256 , (3,3) , activation='relu' ,padding='same', kernel_initializer='he_normal')(normal3)
    layer7 = Conv2D(256 , (3,3) , activation='relu' ,padding='same', kernel_initializer='he_normal')(layer6)
    pool4 = MaxPooling2D()(layer7)


    flatten  = Flatten()(pool4)
    dropout1 = Dropout(rate = 0.2)(flatten)
    dense1 = Dense(units = 256 , activation = 'relu' , kernel_initializer = 'he_normal')(dropout1)
    normal4 = BatchNormalization()(dense1)
    dense2 = Dense(units = 128 , activation = 'relu' , kernel_initializer = 'he_normal')(normal4)
    normal5 = BatchNormalization()(dense2)
    dense3 = Dense(units = 64 , activation = 'relu' , kernel_initializer = 'he_normal')(normal5)
    normal6 = BatchNormalization()(dense3) 
    dense4 = Dense(units = 32 , activation = 'relu' , kernel_initializer = 'he_normal' , kernel_regularizer=keras.regularizers.L1L2())(normal6)
    normal7 = BatchNormalization()(dense4) 
    dense5 = Dense(units = 7 , activation='softmax' ,kernel_initializer="glorot_uniform" , name = 'classifier')(normal7)

    return Model(inputs = input_ ,outputs = dense5)

# %%
model_1 = model1()
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 28, 28, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# _________________________________________________________________
# activation_5 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 1,672,231
# Trainable params: 1,672,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2 = model2()
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 28, 28, 3)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_8 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# activation_9 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# activation_10 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# _________________________________________________________________
# activation_11 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,672,231
# Trainable params: 1,672,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_3 = model3()
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 28, 28, 3)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# activation_12 (Activation)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_13 (Activation)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_14 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# activation_16 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_17 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 1799
# _________________________________________________________________
# activation_18 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,706,151
# Trainable params: 1,706,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_4 = model4()
model_4.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 3)]       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 7, 128)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 3, 3, 256)         295168
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# classifier (Dense)           (None, 7)                 231
# =================================================================
# Total params: 1,275,079
# Trainable params: 1,273,671
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
#plotting model
# keras.utils.plot_model(model)

# %%
model_1.compile(optimizer='adam' , loss = keras.losses.CategoricalCrossentropy() ,metrics = ['accuracy'])
model_2.compile(optimizer='adam' , loss = keras.losses.CategoricalCrossentropy() ,metrics = ['accuracy'])
model_3.compile(optimizer='adam' , loss = keras.losses.CategoricalCrossentropy() ,metrics = ['accuracy'])
model_4.compile(optimizer='adam' , loss = keras.losses.CategoricalCrossentropy() ,metrics = ['accuracy'])

# %%
#Training
print("Training Model 1 Started...")
history1 = model_1.fit(X_train ,y_train ,epochs=20 ,batch_size=128,validation_data=(X_test , y_test) ,callbacks=[learning_rate_reduction, early_stopping])
print("Training Model 1 Completed...")
print("Training Model 2 Started...")
history2 = model_2.fit(X_train ,y_train ,epochs=20 ,batch_size=128,validation_data=(X_test , y_test) ,callbacks=[learning_rate_reduction, early_stopping])
print("Training Model 2 Completed...")
print("Training Model 3 Started...")
history3 = model_3.fit(X_train ,y_train ,epochs=20 ,batch_size=128,validation_data=(X_test , y_test) ,callbacks=[learning_rate_reduction, early_stopping])
print("Training Model 3 Completed...")
print("Training Model 4 Started...")
history4 = model_4.fit(X_train ,y_train ,epochs=20 ,batch_size=128,validation_data=(X_test , y_test) ,callbacks=[learning_rate_reduction, early_stopping])
print("Training Model 4 Completed...")
# Out:
# Training Model 1 Started...
# Epoch 1/20
# 294/294 [==============================] - 11s 13ms/step - loss: 1.2017 - accuracy: 0.5316 - val_loss: 0.7191 - val_accuracy: 0.7455
# Epoch 2/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.5375 - accuracy: 0.8058 - val_loss: 0.3728 - val_accuracy: 0.8663
# Epoch 3/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.2909 - accuracy: 0.8973 - val_loss: 0.2880 - val_accuracy: 0.9015
# Epoch 4/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1859 - accuracy: 0.9345 - val_loss: 0.1782 - val_accuracy: 0.9398
# Epoch 5/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1351 - accuracy: 0.9525 - val_loss: 0.2126 - val_accuracy: 0.9302
# Epoch 6/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1086 - accuracy: 0.9606 - val_loss: 0.1339 - val_accuracy: 0.9609
# Epoch 7/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0925 - accuracy: 0.9668 - val_loss: 0.1306 - val_accuracy: 0.9577
# Epoch 8/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1059 - accuracy: 0.9675 - val_loss: 0.8862 - val_accuracy: 0.6847
# Epoch 9/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1736 - accuracy: 0.9390 - val_loss: 0.1074 - val_accuracy: 0.9680
# Epoch 10/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0549 - accuracy: 0.9810 - val_loss: 0.0963 - val_accuracy: 0.9722
# Epoch 11/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0419 - accuracy: 0.9864 - val_loss: 0.0888 - val_accuracy: 0.9776
# Epoch 12/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0400 - accuracy: 0.9860 - val_loss: 0.1066 - val_accuracy: 0.9754
# Epoch 13/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0366 - accuracy: 0.9877 - val_loss: 0.1043 - val_accuracy: 0.9777
# Epoch 14/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 0.0977 - val_accuracy: 0.9770
# Epoch 15/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0327 - accuracy: 0.9896 - val_loss: 0.1068 - val_accuracy: 0.9760
# Epoch 16/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.1001 - val_accuracy: 0.9730
# Epoch 17/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0835 - val_accuracy: 0.9816
# Epoch 18/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0354 - accuracy: 0.9890 - val_loss: 0.1246 - val_accuracy: 0.9750
# Epoch 19/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.1133 - val_accuracy: 0.9773
# Epoch 20/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0235 - accuracy: 0.9920 - val_loss: 0.1701 - val_accuracy: 0.9655
# Training Model 1 Completed...
# Training Model 2 Started...
# Epoch 1/20
# 294/294 [==============================] - 4s 13ms/step - loss: 1.1371 - accuracy: 0.5628 - val_loss: 0.7540 - val_accuracy: 0.7342
# Epoch 2/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.5446 - accuracy: 0.8054 - val_loss: 0.3815 - val_accuracy: 0.8683
# Epoch 3/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.3013 - accuracy: 0.8941 - val_loss: 0.2650 - val_accuracy: 0.9055
# Epoch 4/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1858 - accuracy: 0.9356 - val_loss: 0.1845 - val_accuracy: 0.9374
# Epoch 5/20
# 294/294 [==============================] - 4s 12ms/step - loss: 0.1203 - accuracy: 0.9573 - val_loss: 0.1249 - val_accuracy: 0.9606
# Epoch 6/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0976 - accuracy: 0.9656 - val_loss: 0.1291 - val_accuracy: 0.9598
# Epoch 7/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0911 - accuracy: 0.9691 - val_loss: 0.1077 - val_accuracy: 0.9681
# Epoch 8/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0460 - accuracy: 0.9846 - val_loss: 0.1042 - val_accuracy: 0.9712
# Epoch 9/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0635 - accuracy: 0.9786 - val_loss: 0.1090 - val_accuracy: 0.9705
# Epoch 10/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0461 - accuracy: 0.9843 - val_loss: 0.0955 - val_accuracy: 0.9734
# Epoch 11/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.1226 - val_accuracy: 0.9680
# Epoch 12/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0435 - accuracy: 0.9848 - val_loss: 0.0925 - val_accuracy: 0.9753
# Epoch 13/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.1005 - val_accuracy: 0.9736
# Epoch 14/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0305 - accuracy: 0.9892 - val_loss: 0.1424 - val_accuracy: 0.9717
# Epoch 15/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0309 - accuracy: 0.9902 - val_loss: 0.0948 - val_accuracy: 0.9793
# Epoch 16/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0825 - val_accuracy: 0.9809
# Epoch 17/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0254 - accuracy: 0.9912 - val_loss: 0.1289 - val_accuracy: 0.9738
# Epoch 18/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.1191 - val_accuracy: 0.9759
# Epoch 19/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.0992 - val_accuracy: 0.9808
# Epoch 20/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0270 - accuracy: 0.9912 - val_loss: 0.1555 - val_accuracy: 0.9664
# Training Model 2 Completed...
# Training Model 3 Started...
# Epoch 1/20
# 294/294 [==============================] - 4s 13ms/step - loss: 1.4019 - accuracy: 0.4344 - val_loss: 0.9949 - val_accuracy: 0.6263
# Epoch 2/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.7802 - accuracy: 0.7101 - val_loss: 0.5773 - val_accuracy: 0.7858
# Epoch 3/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.4417 - accuracy: 0.8357 - val_loss: 0.2985 - val_accuracy: 0.8943
# Epoch 4/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.2890 - accuracy: 0.8923 - val_loss: 0.2152 - val_accuracy: 0.9211
# Epoch 5/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.2074 - accuracy: 0.9230 - val_loss: 0.2071 - val_accuracy: 0.9329
# Epoch 6/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1557 - accuracy: 0.9432 - val_loss: 0.1280 - val_accuracy: 0.9549
# Epoch 7/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1352 - accuracy: 0.9508 - val_loss: 0.1403 - val_accuracy: 0.9523
# Epoch 8/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1059 - accuracy: 0.9613 - val_loss: 0.1083 - val_accuracy: 0.9638
# Epoch 9/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0954 - accuracy: 0.9645 - val_loss: 0.0899 - val_accuracy: 0.9707
# Epoch 10/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0775 - accuracy: 0.9721 - val_loss: 0.1099 - val_accuracy: 0.9662
# Epoch 11/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0780 - accuracy: 0.9720 - val_loss: 0.1078 - val_accuracy: 0.9687
# Epoch 12/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0653 - accuracy: 0.9766 - val_loss: 0.0843 - val_accuracy: 0.9736
# Epoch 13/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0550 - accuracy: 0.9808 - val_loss: 0.1089 - val_accuracy: 0.9700
# Epoch 14/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0600 - accuracy: 0.9793 - val_loss: 0.0858 - val_accuracy: 0.9734
# Epoch 15/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0554 - accuracy: 0.9810 - val_loss: 0.0888 - val_accuracy: 0.9733
# Epoch 16/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0557 - accuracy: 0.9809 - val_loss: 0.1062 - val_accuracy: 0.9710
# Epoch 17/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0353 - accuracy: 0.9880 - val_loss: 0.0881 - val_accuracy: 0.9758
# Epoch 18/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0414 - accuracy: 0.9863 - val_loss: 0.0965 - val_accuracy: 0.9722
# Epoch 19/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0393 - accuracy: 0.9867 - val_loss: 0.0867 - val_accuracy: 0.9767
# Epoch 20/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.1017 - val_accuracy: 0.9713
# Training Model 3 Completed...
# Training Model 4 Started...
# Epoch 1/20
# 294/294 [==============================] - 6s 15ms/step - loss: 1.0744 - accuracy: 0.6065 - val_loss: 0.8910 - val_accuracy: 0.6658
# Epoch 2/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.4519 - accuracy: 0.8345 - val_loss: 0.4826 - val_accuracy: 0.8256
# Epoch 3/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.2701 - accuracy: 0.9021 - val_loss: 0.5423 - val_accuracy: 0.8075
# Epoch 4/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1998 - accuracy: 0.9281 - val_loss: 1.1253 - val_accuracy: 0.7038
# Epoch 5/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1485 - accuracy: 0.9485 - val_loss: 0.2209 - val_accuracy: 0.9237
# Epoch 6/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.1213 - accuracy: 0.9573 - val_loss: 0.1942 - val_accuracy: 0.9268
# Epoch 7/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0998 - accuracy: 0.9649 - val_loss: 0.2966 - val_accuracy: 0.9020
# Epoch 8/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0865 - accuracy: 0.9701 - val_loss: 0.2627 - val_accuracy: 0.9130
# Epoch 9/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0682 - accuracy: 0.9763 - val_loss: 0.2178 - val_accuracy: 0.9332
# Epoch 10/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0622 - accuracy: 0.9785 - val_loss: 0.1427 - val_accuracy: 0.9562
# Epoch 11/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0610 - accuracy: 0.9795 - val_loss: 1.3748 - val_accuracy: 0.6871
# Epoch 12/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0452 - accuracy: 0.9850 - val_loss: 0.2089 - val_accuracy: 0.9341
# Epoch 13/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0430 - accuracy: 0.9853 - val_loss: 0.2183 - val_accuracy: 0.9412
# Epoch 14/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0430 - accuracy: 0.9851 - val_loss: 0.3182 - val_accuracy: 0.9179
# Epoch 15/20
# 294/294 [==============================] - 3s 11ms/step - loss: 0.0390 - accuracy: 0.9871 - val_loss: 0.2364 - val_accuracy: 0.9438
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Training Model 4 Completed...

# %%
#testing
model_1.evaluate(X_test , y_test)
model_2.evaluate(X_test , y_test)
model_3.evaluate(X_test , y_test)
model_4.evaluate(X_test , y_test)
# Out:
# 294/294 [==============================] - 1s 3ms/step - loss: 0.1701 - accuracy: 0.9655
# 294/294 [==============================] - 1s 3ms/step - loss: 0.1555 - accuracy: 0.9664
# 294/294 [==============================] - 1s 3ms/step - loss: 0.1017 - accuracy: 0.9713
# 294/294 [==============================] - 1s 4ms/step - loss: 0.2364 - accuracy: 0.9438
# [0.23640485107898712, 0.9437519907951355]

# %%
#predicting
y_pred1  = model1.predict(X_test).round()
y_pred2  = model2.predict(X_test).round()
y_pred3  = model3.predict(X_test).round()
y_pred4  = model4.predict(X_test).round()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27/200668486.py in <module>
#       1 #predicting
# ----> 2 y_pred1  = model1.predict(X_test).round()
#       3 y_pred2  = model2.predict(X_test).round()
#       4 y_pred3  = model3.predict(X_test).round()
#       5 y_pred4  = model4.predict(X_test).round()
#
# AttributeError: 'function' object has no attribute 'predict'

# %%
target_names = [f"{classes[i]}" for i in range(7)]
print(classification_report(y_test , y_pred1 , target_names =target_names ))

# %%
target_names = [f"{classes[i]}" for i in range(7)]
print(classification_report(y_test , y_pred2 , target_names =target_names ))

# %%
target_names = [f"{classes[i]}" for i in range(7)]
print(classification_report(y_test , y_pred3 , target_names =target_names ))

# %%
target_names = [f"{classes[i]}" for i in range(7)]
print(classification_report(y_test , y_pred4 , target_names =target_names ))

# %%
#training acc vs testing acc graph
def plot(history, model_name, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)
    
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, 'ro-',label='Training Accuracy', )
    plt.plot(epochs_range, val_acc, 'go-', label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'Training and Validation Accuracy {model_name}')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, 'ro-', label='Training Loss')
    plt.plot(epochs_range, val_loss, 'go-', label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'Training and Validation Loss {model_name}')
    plt.show()

# %%
plot(history1, 'model 1', epochs = len(history1.history['loss']))

# %%
plot(history2, 'model 2', epochs = len(history2.history['loss']))

# %%
plot(history3, 'model 3', epochs = len(history3.history['loss']))

# %%
plot(history4, 'model 4', epochs = len(history4.history['loss']))

# %% [markdown]
# ****Saving all the models

# %%
model_1.save("/kaggle/working/model1.h5")
model_2.save("/kaggle/working/model2.h5")
model_3.save("/kaggle/working/model3.h5")
model_4.save("/kaggle/working/model4.h5")

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

# Load the individual models
model1 = load_model('model1.h5')
model2 = load_model('model2.h5')
model3 = load_model('model3.h5')
model4 = load_model('model4.h5')

# Making model names unique
model1._name = 'model1'
model2._name = 'model2'
model3._name = 'model3'
model4._name = 'model4'

# Create a new input layer that matches the input shape of the individual models
ensemble_input = tf.keras.Input(shape=model1.input_shape[1:])

# Get the outputs of each model
output1 = model1(ensemble_input)
output2 = model2(ensemble_input)
output3 = model3(ensemble_input)
output4 = model4(ensemble_input)

# Average the outputs
ensemble_output = tf.keras.layers.Average()([output1, output2, output3, output4])

# Create the ensemble model
ensemble_model = tf.keras.Model(inputs=ensemble_input, outputs=ensemble_output)

# %%
# we will retrain our final model for some epochs to get better accuracy
model5 = ensemble_model
model5.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# model1 (Sequential)             (None, 7)            1672231     input_2[0][0]
# __________________________________________________________________________________________________
# model2 (Sequential)             (None, 7)            1672231     input_2[0][0]
# __________________________________________________________________________________________________
# model3 (Sequential)             (None, 7)            1706151     input_2[0][0]
# __________________________________________________________________________________________________
# model4 (Functional)             (None, 7)            1275079     input_2[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 7)            0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
# ==================================================================================================
# Total params: 6,325,692
# Trainable params: 6,324,284
# Non-trainable params: 1,408
# __________________________________________________________________________________________________

# %%
model5.compile(optimizer='adam' , loss = keras.losses.CategoricalCrossentropy() ,metrics = ['accuracy'])
print("Training Model 5 Started...")
history = model5.fit(X_train ,y_train ,epochs=7 ,batch_size=128,validation_data=(X_test , y_test) ,callbacks=[learning_rate_reduction, early_stopping])
print("Training Model 5 Completed...")
# Out:
# Training Model 5 Started...
# Epoch 1/7
# 294/294 [==============================] - 13s 37ms/step - loss: 0.0217 - accuracy: 0.9993 - val_loss: 0.0884 - val_accuracy: 0.9798
# Epoch 2/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0304 - accuracy: 0.9987 - val_loss: 0.0858 - val_accuracy: 0.9831
# Epoch 3/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0345 - accuracy: 0.9985 - val_loss: 0.1173 - val_accuracy: 0.9802
# Epoch 4/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0298 - accuracy: 0.9985 - val_loss: 0.1039 - val_accuracy: 0.9813
# Epoch 5/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0337 - accuracy: 0.9982 - val_loss: 0.1123 - val_accuracy: 0.9814
# Epoch 6/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0350 - accuracy: 0.9982 - val_loss: 0.1858 - val_accuracy: 0.9737
# Epoch 7/7
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0364 - accuracy: 0.9980 - val_loss: 0.1385 - val_accuracy: 0.9810
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Training Model 5 Completed...

# %%
model5.evaluate(X_test , y_test)
#predicting
y_pred  = model5.predict(X_test).round()

# Save the model
model5.save('/kaggle/working/model5.h5')
# Out:
# 294/294 [==============================] - 2s 5ms/step - loss: 0.1385 - accuracy: 0.9810

# %%
target_names = [f"{classes[i]}" for i in range(7)]
print(classification_report(y_test , y_pred , target_names =target_names ))
# Out:
#                                                                precision    recall  f1-score   support
#
# ('akiec', 'Actinic keratoses and intraepithelial carcinomae')       1.00      1.00      1.00      1295
#                              ('bcc', ' basal cell carcinoma')       0.99      1.00      0.99      1323
#                      ('bkl', 'benign keratosis-like lesions')       0.99      0.98      0.98      1351
#                                      ('df', 'dermatofibroma')       1.00      1.00      1.00      1392
#                                   ('nv', ' melanocytic nevi')       0.99      0.86      0.92      1346
#               ('vasc', ' pyogenic granulomas and hemorrhage')       1.00      1.00      1.00      1292
#                                           ('mel', 'melanoma')       0.96      0.99      0.98      1388
#
#                                                     micro avg       0.99      0.98      0.98      9387
#                                                     macro avg       0.99      0.98      0.98      9387
#                                                  weighted avg       0.99      0.98      0.98      9387
#                                                   samples avg       0.98      0.98      0.98      9387

# %%
plot(history, 'model 5', epochs = len(history.history['loss']))

# %%
#visualizing prediction
correct = np.nonzero(y_pred == y_test)[1]
fig, axes = plt.subplots(1,5)
fig.set_size_inches(10, 10)
k = 0 
for c in correct[:5]:
    plt.subplot(2,5,k+1)
    plt.imshow(X_test[k].reshape(28,28,3) , interpolation='none')
    plt.title(f"Predicted : {classes[y_pred[k].argmax(axis = 0)][0]},\nActual :{classes[y_test[k].argmax(axis = 0)][0]} ")
    plt.tight_layout()
    plt.grid(False)
    k += 1

# %%
from keras.preprocessing import image
import numpy as np
import keras

# Load and prepare the image
m = keras.models.load_model("/kaggle/working/model5.h5")
img_path_1 = '/kaggle/input/google-images/Basal.png' 
img_path_2 = '/kaggle/input/google-images/Melanocytic.png'
img1 = image.load_img(img_path_1, target_size=(28, 28))
img2 = image.load_img(img_path_2, target_size=(28, 28))
img_array_1 = image.img_to_array(img1)
img_array_1 = np.expand_dims(img_array_1, axis=0) 

img_array_2 = image.img_to_array(img2)
img_array_2 = np.expand_dims(img_array_2, axis=0) 

# Predict the cancer type
prediction_1 = m.predict(img_array_1)
prediction_2 = m.predict(img_array_2)
print(prediction_1, prediction_2)
# Out:
# [[5.15998124e-07 7.47288167e-01 7.37135952e-09 1.05601076e-10
#   2.52710819e-01 1.21946855e-10 5.06863898e-07]] [[6.8537773e-08 4.4161337e-03 2.0240514e-09 8.3526197e-10 9.9558294e-01
#   4.9886839e-12 8.7718183e-07]]

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

max1 = 0
max2 = 0
x = 0
y = 0

for i in range(7):
    if (prediction_1[0][i] > max1).any():
        max1 = prediction_1[0][i]
        x = i
    if (prediction_2[0][i] > max2).any():
        max2 = prediction_2[0][i]
        y = i

print("Image 1: ", classes[x],"Image 2:", classes[y])
# Out:
# Image 1:  ('bcc', ' basal cell carcinoma') Image 2: ('nv', ' melanocytic nevi')
